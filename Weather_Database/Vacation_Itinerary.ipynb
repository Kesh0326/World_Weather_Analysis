# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from configcopy import g_key

# Configure gmaps
gmaps.configure(api_key = g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head(50)
# Out:
#     City_ID               City Country  Max Temp          Current Description  \
# 0         1       Saint George      US     75.00                    clear sky
# 1         8               Hilo      US     82.99                   few clouds
# 2        11            Tucuman      AR     78.80                    clear sky
# 3        14            Angoche      MZ     77.74                    clear sky
# 4        15              Vaini      TO     71.60                broken clouds
# 5        17              Dakar      SN     84.20                    clear sky
# 6        18    Arraial Do Cabo      BR     75.20                broken clouds
# 7        21          Aguililla      MX     77.16                   light rain
# 8        24        Port-Gentil      GA     80.60             scattered clouds
# 9        27            Rikitea      PF     75.85                    clear sky
# 10       29              Kapaa      US     80.01                   few clouds
# 11       31             Agadir      MA     77.00                    clear sky
# 12       33        Keti Bandar      PK     79.20                    clear sky
# 13       35         Port Blair      IN     80.44                moderate rain
# 14       40      Marsh Harbour      BS     82.60                    clear sky
# 15       41           Meulaboh      ID     76.51                   light rain
# 16       43       San Patricio      US     73.00                   few clouds
# 17       45          Bathsheba      BB     77.00              overcast clouds
# 18       46         Coahuayana      MX     82.40                broken clouds
# 19       52          Hithadhoo      MV     82.94                broken clouds
# 20       59        Gainesville      US     73.00                    clear sky
# 21       60            Betioky      MG     75.52                    clear sky
# 22       64          Carnarvon      AU     71.60              overcast clouds
# 23       69            Mayumba      GA     76.48                   light rain
# 24       74          Sinnamary      GF     84.65                broken clouds
# 25       75         Butaritari      KI     81.28                moderate rain
# 26       76               Lamu      KE     77.94                   light rain
# 27       77        Bandarbeyla      SO     78.49                    clear sky
# 28       78     Cabo San Lucas      MX     87.80             scattered clouds
# 29       79             Bonthe      SL     80.02                broken clouds
# 30       80            Kahului      US     78.80             scattered clouds
# 31       84      Saint-Georges      GD     87.80             scattered clouds
# 32       90            Isangel      VU     76.91                   light rain
# 33       91       Puerto Ayora      EC     82.40                   few clouds
# 34       92              Kieta      PG     78.30              overcast clouds
# 35       97             Sibiti      CG     70.39              overcast clouds
# 36      100              Natal      BR     82.40                broken clouds
# 37      108           Kalmunai      LK     79.79         heavy intensity rain
# 38      109             Japura      ID     74.03              overcast clouds
# 39      112               Aden      YE     82.54                    clear sky
# 40      113            Jalingo      NG     80.40                broken clouds
# 41      116         Varkkallai      IN     82.40                         mist
# 42      117          Namatanai      PG     80.10             scattered clouds
# 43      118            Mandera      KE     83.34              overcast clouds
# 44      124            Sawakin      SD     84.90                    clear sky
# 45      127            Bubaque      GW     84.90              overcast clouds
# 46      132              Alofi      NU     73.40  light intensity shower rain
# 47      140             Padang      ID     77.94              overcast clouds
# 48      141             Touros      BR     84.20                   few clouds
# 49      142  Sao Joao Da Barra      BR     75.20                broken clouds
#
#       Lat     Lng                                         Hotel Name
# 0   37.10 -113.58                        Best Western Plus Abbey Inn
# 1   19.73 -155.09                                Hilo Hawaiian Hotel
# 2  -26.82  -65.22                               Dallas Hotel Tucuman
# 3  -16.23   39.91                                 Guest House HESADA
# 4  -21.20 -175.20                                Keleti Beach Resort
# 5   14.69  -17.44                                      Novotel Dakar
# 6  -22.97  -42.03                                Pousada Porto Praia
# 7   18.73 -102.73                                                NaN
# 8   -0.72    8.78                                 Fengshui Residence
# 9  -23.12 -134.97                                     Pension Maro'i
# 10  22.08 -159.32             Sheraton Kauai Resort at Coconut Beach
# 11  30.42   -9.60                             Iberostar Founty Beach
# 12  24.14   67.45                             Haji laloo memon house
# 13  11.67   92.75                          Fortune Resort Bay Island
# 14  26.54  -77.06                                 Abaco Beach Resort
# 15   4.14   96.13                                          Kost Pria
# 16  28.02  -97.52                                 Motel 6 Sinton, TX
# 17  13.22  -59.52                                     Atlantis Hotel
# 18  18.73 -103.68                                    Hotel Los Arcos
# 19  -0.60   73.08                                  Scoop Guest House
# 20  29.65  -82.32                         Wyndham Garden Gainesville
# 21 -23.72   44.38                            Bungalows Acacias Hotel
# 22 -24.87  113.63                              Hospitality Carnarvon
# 23  -3.43   10.66                                      LIKWALE LODGE
# 24   5.38  -52.95                     ALETHEIA Appartement Sinnamary
# 25   3.07  172.79                                 Isles Sunset Lodge
# 26  -2.27   40.90                                         Lamu House
# 27   9.49   50.81                                 REER XOOSHLE GROUP
# 28  22.89 -109.91                             Hotel Tesoro Los Cabos
# 29   7.53  -12.51                             Bonthe Holiday Village
# 30  20.89 -156.47                                 Maui Seaside Hotel
# 31  12.06  -61.75                                       Siesta Hotel
# 32 -19.55  169.27                        Volcano Sea View Tree House
# 33  -0.74  -90.35                          Finch Bay Galapagos Hotel
# 34  -6.22  155.63                                                NaN
# 35  -3.68   13.35                                     Hotel Mapila 1
# 36  -5.79  -35.21                           Villa Park Hotel | Natal
# 37   7.42   81.82                                           VS Villa
# 38  -0.32  102.35                                   Rumah mbah Jamah
# 39  12.78   45.04                                 Sama Emirate Hotel
# 40   8.88   11.37                                     Debright Motel
# 41   8.73   76.71  SPOT ON 72723 Pathanjali Ayurveda Yoga Centre(...
# 42  -3.67  152.43                                    Namatanai Hotel
# 43   3.94   41.87                          Kornesh Hotel and Lodging
# 44  19.11   37.33                                        فندق الدويم
# 45  11.28  -15.83                                 Casa Dora, Bubaque
# 46 -19.06 -169.92                                      Taloa Heights
# 47  -0.95  100.35                                     Mercure Padang
# 48  -5.20  -35.46                                    INN NEW HORIZON
# 49 -21.64  -41.05                            Pousada Porto De Canoas

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
vacation_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df['Max Temp']
fig = gmaps.figure(center=(30.0, 31.0), zoom_level = 1.5)
heat_layer = gmaps.heatmap_layer(locations, weights = max_temp, dissipating = False, max_intensity = 300, point_radius = 4)
marker_layer = gmaps.marker_layer(locations, info_box_content = vacation_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
params = {"radius": 5000, "types": "lodging", "key": g_key, "location": "-22.97, -42.03"}

# Use base URL to search for hotels.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params = params).json()
hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AcnaJv2ROm-0_CjQjptgUD1cBPFy1VYy4ZQflPp7aXbeSWGXAUHKVkQfwfpiVfIF0bHib6oCIaccSZ6J6PyAKMg40JB6uc3GSh9zz8gTUs4NazTsiUylgJr7NeukzKCwXQEGQuiboEJPT5Boeh0JXUxqWoyiVIQyTN_NL1qZedvE76HCPItVxJm7MlBKcGHZk2TeNHmgCeH7zDyohxxXFpk5nv46kCHKRwrBq16xE2bQVRBLN869EHia3J5V_y9AthC11RGjZanQPe-D1SRwvGuTYsXcZFJ0lyF-kkvWA6hsgUOJs2Mp1TBsNedqyR7LOwfylL_1T3oDUNZ9Bcn73DMGghqiS6wP2Xriu1_hXddzwCdY9n_Qs1uOIP4-iKg5LJyUWTx_YL2anYBYlvAbLj-8uMNbTWYIcB9EEPrxGA8WVuyj1aljOk0',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9778162, 'lng': -42.0238837},
#     'viewport': {'northeast': {'lat': -22.9764117197085,
#       'lng': -42.0225476697085},
#      'southwest': {'lat': -22.9791096802915, 'lng': -42.02524563029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Pousada Porto Praia',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1360,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108429151867043498766">Pousada Porto Praia</a>'],
#      'photo_reference': 'CmRaAAAAKFsMCCqHfKydEMDqq1tgoJLHLvy0_525Ab7pcGlNreaA7eu-5t2IdonlA2thE5Gk52Ye6P99gkWaaxilGrQrvQ1rEZ9gSqPdEeClH7DAT4A7aTxCCjMWMJq6Qe7MSbf5EhCv9uBjOCS-47cR_2YhN-7YGhQe63Cu6dZ1ngP5zVLM_YyAxTh6tA',
#      'width': 2048}],
#    'place_id': 'ChIJCzyENW0ZlwARml4yd1nWNbg',
#    'plus_code': {'compound_code': '2XCG+VC Macedônia, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XCG+VC'},
#    'rating': 4.2,
#    'reference': 'ChIJCzyENW0ZlwARml4yd1nWNbg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 411,
#    'vicinity': 'Rua Vilas Bôas, 161 - Macedônia, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9587565, 'lng': -42.0259149},
#     'viewport': {'northeast': {'lat': -22.9574790697085,
#       'lng': -42.0247155697085},
#      'southwest': {'lat': -22.9601770302915, 'lng': -42.0274135302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Ocean View Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109212704429738960237">Ocean View Hotel</a>'],
#      'photo_reference': 'CmRaAAAA31FoKwcNR86HWfjm-MUy6IwQH1E1Xx_YBA9V6SeCb1B7RulCK8yo0n_BmLNrE41tJFbvfnB6rJTbBCGDk0N5HQWqPQWCYdo-_Z6fDu3YhuJmp2a3i4cN5DA-CsFj5LuqEhAUFlR84xa5NfTES25SGDmoGhRYWcXF7yxorRrOOoit-D8GV7Dcxg',
#      'width': 1280}],
#    'place_id': 'ChIJeZNO5mEZlwARLA3A1MstjfA',
#    'plus_code': {'compound_code': '2XRF+FJ Prainha, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XRF+FJ'},
#    'rating': 4.4,
#    'reference': 'ChIJeZNO5mEZlwARLA3A1MstjfA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 671,
#    'vicinity': 'Rua, Avenida Alfredo Dante Fassini, 01 - Prainha, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9782905, 'lng': -42.0270796},
#     'viewport': {'northeast': {'lat': -22.9769893197085,
#       'lng': -42.0257481197085},
#      'southwest': {'lat': -22.9796872802915, 'lng': -42.0284460802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hostel Villas Boas',
#    'photos': [{'height': 636,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117825198970274766060">Hostel Villas Boas</a>'],
#      'photo_reference': 'CmRaAAAAU4YBKlFgPVUNJc5TbrpyGCCENkUea0iZ_dr9l9c4if9o8R-MDWzEZfVQMpwtagQnVJ2orVp0on5tlSqOtvSqs_LvehrbXjuURASMBg1KMuVAiIQn0Jpp6SPjSmCkbcBaEhDL6POviC0Ccj2hMQ3byugdGhRptYqkH-1r3Bk_rklQLwD_HhWEow',
#      'width': 960}],
#    'place_id': 'ChIJrQSJlGwZlwARwWMofIE5cKs',
#    'plus_code': {'compound_code': '2XCF+M5 Vila Canaa, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XCF+M5'},
#    'rating': 4.3,
#    'reference': 'ChIJrQSJlGwZlwARwWMofIE5cKs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 346,
#    'vicinity': 'Rua Vilas Bôas, 440 - Vila Canaa, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.975268, 'lng': -42.02918700000001},
#     'viewport': {'northeast': {'lat': -22.9739427697085,
#       'lng': -42.0278418697085},
#      'southwest': {'lat': -22.9766407302915, 'lng': -42.0305398302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Praia Grande Pousada',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1746,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117108862838951045343">FER LACENTRE</a>'],
#      'photo_reference': 'CmRaAAAAowzrkiATgQTq22CfQCCbr9ztesKhgatJb6FUjeBH_RiyV906lzBbqGk9jzg64ce7DLrJXbjaqPC-UdmITt3FYdyyN-cZ86sYXHlcqDF89BuMEsgKo8CpaPznW17Tx9tvEhBFrnYfHS6GftB7ROZuBY5mGhRLokCqBxiSZHVfjgiOCwxqOZrXtg',
#      'width': 3104}],
#    'place_id': 'ChIJERM_fnIZlwARIECXK6_BoX4',
#    'plus_code': {'compound_code': '2XFC+V8 Vila Canaa, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XFC+V8'},
#    'rating': 4.4,
#    'reference': 'ChIJERM_fnIZlwARIECXK6_BoX4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 191,
#    'vicinity': 'Travessa José Francisco Borba, 7 - Vila Canaa, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.973009, 'lng': -42.0222861},
#     'viewport': {'northeast': {'lat': -22.9716342697085,
#       'lng': -42.02101301970849},
#      'southwest': {'lat': -22.97433223029151, 'lng': -42.02371098029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'HI Marina dos Anjos',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104424066332699949643">Pousada Marina dos Anjos</a>'],
#      'photo_reference': 'CmRaAAAATOhkCrjRAcgMsPgHi8_C_eKPY1AIMGE259JPjUIZgbqXhz2423UgT2rs9eE3fFP5626YnyOJeKwTKGw5PY9R1aMR41Ebe4bzSOi_etqWvdt5E2jPdQl4ZAWZYDsOhY2LEhAkykhK8Un3TkI4aC8Ft88tGhQrx6aVe4-FjvEwfALHVUTKSgx6fw',
#      'width': 2880}],
#    'place_id': 'ChIJTUMDH2kZlwARPavgpZzkjpY',
#    'plus_code': {'compound_code': '2XGH+Q3 Praia dos Anjos, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XGH+Q3'},
#    'rating': 4.5,
#    'reference': 'ChIJTUMDH2kZlwARPavgpZzkjpY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 203,
#    'vicinity': 'Rua Bernardo Lens, 145 - Praia dos Anjos, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9694785, 'lng': -42.0226451},
#     'viewport': {'northeast': {'lat': -22.9680945697085,
#       'lng': -42.0213443697085},
#      'southwest': {'lat': -22.9707925302915, 'lng': -42.0240423302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Arraial Flats',
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116057736355677134774">Vall Gomez</a>'],
#      'photo_reference': 'CmRZAAAAiD48ai--RDjmMdSAJIkP10x5sfS4Wcabho68rsbvgYrOuD_Qs40EcFpFKHZgkijHTDsyNDT7Cw31T0b5KgWniIZ9O2N4uQl_LyiDNFl9bJh0Xxq-Y-aOUpKsLfyV0wcPEhAjdJNkb0inmk8Ufurj_hFLGhRBos_JQ5wO7DUDltbqZGs8zd2stw',
#      'width': 4608}],
#    'place_id': 'ChIJZVY9FGYZlwARubKWI_QJ1vw',
#    'plus_code': {'compound_code': '2XJG+6W Centro, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XJG+6W'},
#    'rating': 4.4,
#    'reference': 'ChIJZVY9FGYZlwARubKWI_QJ1vw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 41,
#    'vicinity': 'Praça Euclides Soares de Aguiar, 3 - Centro, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.96897899999999, 'lng': -42.0194444},
#     'viewport': {'northeast': {'lat': -22.9675447197085,
#       'lng': -42.0180548197085},
#      'southwest': {'lat': -22.9702426802915, 'lng': -42.0207527802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Pousada Estalagem do Porto',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111354997572753926422">Pousada Estalagem do Porto</a>'],
#      'photo_reference': 'CmRaAAAAB5kiuAMR2xFvZGvpjA9lFg9FV5hwnAdy-bolUtK7K3uDeB-xr4J9U9OJuZSBKqAh7fTc73fUW65_TRQ5889yT88CBDk6AdUTvs5jN2rIat7epjoWQvXAyuPXN80JKCQdEhBK7OgTSYyErDk-zKUTtcryGhQtgCSyMPjcHruj8dAo9maHhSA3vA',
#      'width': 2048}],
#    'place_id': 'ChIJ-ag2g2cZlwARJZqsJxVD3V8',
#    'plus_code': {'compound_code': '2XJJ+C6 Praia dos Anjos, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XJJ+C6'},
#    'rating': 4.4,
#    'reference': 'ChIJ-ag2g2cZlwARJZqsJxVD3V8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3461,
#    'vicinity': 'Rua Ipanema, 12 - Praia dos Anjos, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.97815, 'lng': -42.03247400000001},
#     'viewport': {'northeast': {'lat': -22.9767927697085,
#       'lng': -42.0311759697085},
#      'southwest': {'lat': -22.9794907302915, 'lng': -42.0338739302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Pousada Sentinels of the Sea - Arraial do Cabo - RJ',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2736,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109581323324757495345">Albert Da Costa</a>'],
#      'photo_reference': 'CmRaAAAAs9pQMfvLP1-euI0EVmctNHFM19ngy2GfhmhFbKJpLOrfG1ATEBIZ9jM5VHbXxhVaZ-r7wWAjQR6nuwXDFSYm0Q-iv94Opw1QcCvAJb5vshRqR_VqYaCSR18dmzzFAbdpEhBnncYZMNVRT57fBcZBLtXVGhS808pKxjTmB2FRrhRdyGSWSgQG2g',
#      'width': 3648}],
#    'place_id': 'ChIJwUvA5nIZlwARboeL1Hp6Hvc',
#    'plus_code': {'compound_code': '2XC9+P2 Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XC9+P2'},
#    'rating': 4.6,
#    'reference': 'ChIJwUvA5nIZlwARboeL1Hp6Hvc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 403,
#    'vicinity': 'Rua de Castro Neto, s6, Rua Pontal do Atalaia, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9751139, 'lng': -42.0227361},
#     'viewport': {'northeast': {'lat': -22.9737770197085,
#       'lng': -42.0213466197085},
#      'southwest': {'lat': -22.9764749802915, 'lng': -42.02404458029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Acquarela Hostel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 676,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104647675483326742653">Acquarela Hostel</a>'],
#      'photo_reference': 'CmRaAAAAS6K4btmqpFPUZx90pk5D_lm5ZEO-URQz4p7MJzCLzFaN-OMUX1KwggNYA401h-ITfiikM_coPy_POlVhRGRHEUpNAZKtP2dHje5as5AASm7p1AE3GsbH9FwT0OaxIvxrEhDW6bw5qMjwFHB3RqUC_kztGhR_05bL1VVZlm9BdNA5CagTWbLcHg',
#      'width': 1200}],
#    'place_id': 'ChIJoe0LWQ0ZlwARv-c4_4TKZzY',
#    'plus_code': {'compound_code': '2XFG+XW Praia dos Anjos, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XFG+XW'},
#    'rating': 4.5,
#    'reference': 'ChIJoe0LWQ0ZlwARv-c4_4TKZzY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 169,
#    'vicinity': 'Rua Carlos Calixto, 92 - Praia dos Anjos, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9735667, 'lng': -42.0309019},
#     'viewport': {'northeast': {'lat': -22.9721606697085,
#       'lng': -42.0296079197085},
#      'southwest': {'lat': -22.9748586302915, 'lng': -42.0323058802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Pousada Caminho do Sol',
#    'photos': [{'height': 2699,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113661955360660013135">Hotel Pousada Caminho do Sol</a>'],
#      'photo_reference': 'CmRaAAAA6uR3W7D81S99JMyZub257uzXgXPvHkjyjpfGvL9saOHTZgoLub_A1PF4t0m3zfA0SQiYrzs9S4hhwG3OWqB9HDJq_U-yyqDoyNqn3ocJP4F7G-YrnYz-DKjXCotPgutxEhArbGRcLGdYaOXczhInqWsAGhRG7CHzNIxJ6E4LMglesOA8JWdaOQ',
#      'width': 4032}],
#    'place_id': 'ChIJ22rwMXIZlwARi_C7tOx2TKw',
#    'plus_code': {'compound_code': '2XG9+HJ Praia Grande, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XG9+HJ'},
#    'rating': 4.6,
#    'reference': 'ChIJ22rwMXIZlwARi_C7tOx2TKw',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 655,
#    'vicinity': 'Rua Miguel Ângelo, 55 - Praia Grande, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9698963, 'lng': -42.0211067},
#     'viewport': {'northeast': {'lat': -22.9684978197085,
#       'lng': -42.0197110697085},
#      'southwest': {'lat': -22.97119578029151, 'lng': -42.0224090302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Pousada Rayer Land',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113482452483291648980">Fredy Ficht</a>'],
#      'photo_reference': 'CmRaAAAAUetGSB36T55LZ1dMmAbijUdRO2E28LInxOQ-kF_q-FEfxAL3Ndl1bm2q6Pr-2wEzqUCx-DpJwJ9mfmP8zbmx3C-eKsBAWnc18kxcSvI-QcXBVNsgaQRcHspcAG4TR-4QEhDtEm7XfvQNiiT5AlshxLqpGhS9Y-t2tArWni8MdRvrqvMDWemTog',
#      'width': 4032}],
#    'place_id': 'ChIJabIEy2cZlwARZFPvto1H-8c',
#    'plus_code': {'compound_code': '2XJH+2H Praia dos Anjos, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XJH+2H'},
#    'rating': 4.2,
#    'reference': 'ChIJabIEy2cZlwARZFPvto1H-8c',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 573,
#    'vicinity': 'Rua Joaquim Martins Fialho, 3 - Praia dos Anjos, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.93017069999999,
#      'lng': -42.04062489999999},
#     'viewport': {'northeast': {'lat': -22.9288222697085,
#       'lng': -42.0393219197085},
#      'southwest': {'lat': -22.9315202302915, 'lng': -42.0420198802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Pousada Vida Boa Praia',
#    'photos': [{'height': 2608,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104113865550062067040">Déborah Oliveira Farias Hansen</a>'],
#      'photo_reference': 'CmRaAAAA65xXjzB0Kkom8l3Fp2c4MMq-ELt8q6c0sDZCI6cUAMrzotpyHE0ZenfUYzLRV28OKpslHJQD-LUfuj04t4HwOwmlJukn_vFBPpktwI5hbLhF9lsBgE36ErXaB8I43iShEhA1Hr3KLzGjxwuZrFQzxeV-GhQPtCSziugEyPj7wbRYcx1VoL-xBg',
#      'width': 4632}],
#    'place_id': 'ChIJoamRc0salwARawTNAPQjZqg',
#    'plus_code': {'compound_code': '3X95+WQ Foguete, Cabo Frio - State of Rio de Janeiro, Brazil',
#     'global_code': '589V3X95+WQ'},
#    'rating': 4.3,
#    'reference': 'ChIJoamRc0salwARawTNAPQjZqg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 473,
#    'vicinity': 'Rua da Restinga, 1 - Foguete, Cabo Frio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9680006, 'lng': -42.0245918},
#     'viewport': {'northeast': {'lat': -22.9666517697085,
#       'lng': -42.0232117197085},
#      'southwest': {'lat': -22.9693497302915, 'lng': -42.0259096802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Suíte Central',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109169885952248370444">Suíte Central</a>'],
#      'photo_reference': 'CmRaAAAAk9J5qDlApWd052B-BpQCzUQ65T_SCPlC83t--Iipt_I8pSHRpxUL-CUfdOdfFu_ycaYMFhFuULht68siU0j6mtpqGzyFQRn3BzvAg3HFnA-VmXKvkti2ZOkniysgopDYEhDnhAnKuqZXtLfeKAR-0EAvGhS6MIxj3pQJ_pnVO_P4dh65nOHajg',
#      'width': 960}],
#    'place_id': 'ChIJ6zlez2UZlwARwqpBtu1IpVo',
#    'plus_code': {'compound_code': '2XJG+Q5 Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XJG+Q5'},
#    'rating': 5,
#    'reference': 'ChIJ6zlez2UZlwARwqpBtu1IpVo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Rua Benjamin Constant, 06 - CASA, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.970433, 'lng': -42.02619},
#     'viewport': {'northeast': {'lat': -22.9690763697085,
#       'lng': -42.02491576970849},
#      'southwest': {'lat': -22.9717743302915, 'lng': -42.02761373029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Suite Marechal',
#    'photos': [{'height': 2304,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112825193627900191991">Fernando Gimenez</a>'],
#      'photo_reference': 'CmRaAAAAuf1JjWaMc3IqajGnxYpkj8dA4wW206KMAONvEm3VOuHTwsjVSbe2bAcaLhyQGysqa8dZMSG8JxpJv-6DNJ6abQfNypwCIJLep7xhj_Yp0Cj_sRGwh-U3kZv-6f7ZWmVGEhCQEuPEoC2HgHzzdq9BPBQ7GhQS2KrT0_rdo0siiqMuEQsL-5Bjuw',
#      'width': 4096}],
#    'place_id': 'ChIJwSZndW8ZlwARNZM1_2rHqZk',
#    'plus_code': {'compound_code': '2XHF+RG Sítio, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XHF+RG'},
#    'rating': 5,
#    'reference': 'ChIJwSZndW8ZlwARNZM1_2rHqZk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Rua Marechal Deodoro da Fonseca, 49 - Sítio, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9716167, 'lng': -42.0284367},
#     'viewport': {'northeast': {'lat': -22.9702689697085,
#       'lng': -42.0271300197085},
#      'southwest': {'lat': -22.9729669302915, 'lng': -42.0298279802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Doce Lar Hostel',
#    'photos': [{'height': 720,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114585559310319655682">Doce Lar Hostel</a>'],
#      'photo_reference': 'CmRaAAAAU7BBbGtRmbgqxmNSvoxmwlau2mMDEV0gF02LfH_wnbrCuXTQh-em8rPsfz0Vh6OVwlnuU6l3TwUat4S-SGeB8MQ4IMqoFya-ssGX0Dd-nQZBQhEWdK0uex-5fPUyCHG6EhB-9tzhdUTpud55lA68wRmqGhSuNbZNQ9t0_HZDzP5KkRwJ89aOqQ',
#      'width': 960}],
#    'place_id': 'ChIJOyRwNHAZlwARipPGTs8C0rc',
#    'plus_code': {'compound_code': '2XHC+9J Praia Grande, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XHC+9J'},
#    'rating': 4.6,
#    'reference': 'ChIJOyRwNHAZlwARipPGTs8C0rc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 14,
#    'vicinity': 'Rua Francisco P. Mendonça - Praia Grande, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9682247, 'lng': -42.02788569999999},
#     'viewport': {'northeast': {'lat': -22.9668755697085,
#       'lng': -42.0265365697085},
#      'southwest': {'lat': -22.9695735302915, 'lng': -42.0292345302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Loft Centro',
#    'place_id': 'ChIJ8fUiW2UZlwAR90QqCq_BKqc',
#    'plus_code': {'compound_code': '2XJC+PR Centro, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XJC+PR'},
#    'rating': 3.2,
#    'reference': 'ChIJ8fUiW2UZlwAR90QqCq_BKqc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 9,
#    'vicinity': 'Rua Osvaldo Cruz, 53 - Centro, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9595919, 'lng': -42.0255744},
#     'viewport': {'northeast': {'lat': -22.9582774697085,
#       'lng': -42.02418246970851},
#      'southwest': {'lat': -22.9609754302915, 'lng': -42.02688043029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Pousada Thetis',
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104453182055441232642">maria cristina de jesus</a>'],
#      'photo_reference': 'CmRaAAAAD_byrrdpZ1xTLwgfRZMUbZHGLZrWslD9iyPqO6SEm30kAV2mQVCrw1RIvujuz0rSGn2ORTbfQn-XVqZONK5qwTSv_QMoIP7HN7ApTaD9awa7O5porsXvwrh3wgmmwis6EhDnmhdQhrhDJouHuUYWcnmvGhSZeaZ3os-AxZA49ItUc-kiTFFNGg',
#      'width': 4160}],
#    'place_id': 'ChIJC_WTYmIZlwARjM34S0XILaI',
#    'plus_code': {'compound_code': '2XRF+5Q Prainha, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XRF+5Q'},
#    'rating': 3.9,
#    'reference': 'ChIJC_WTYmIZlwARjM34S0XILaI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 439,
#    'vicinity': 'Rua da Prainha, 3 - Prainha, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9663487, 'lng': -42.0332055},
#     'viewport': {'northeast': {'lat': -22.96492736970849,
#       'lng': -42.0318835197085},
#      'southwest': {'lat': -22.9676253302915, 'lng': -42.0345814802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Apartamento Luxo em Arraial do Cabo- RJ',
#    'place_id': 'ChIJx1YYG3oZlwARHrGr4D1vdeE',
#    'plus_code': {'compound_code': '2XM8+FP Centro, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XM8+FP'},
#    'reference': 'ChIJx1YYG3oZlwARHrGr4D1vdeE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Rua Rebeche, 20 - Centro, Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9684858, 'lng': -42.02112099999999},
#     'viewport': {'northeast': {'lat': -22.96713356970849,
#       'lng': -42.0197777197085},
#      'southwest': {'lat': -22.9698315302915, 'lng': -42.0224756802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Lar Hostel',
#    'place_id': 'ChIJm3RjAGcZlwARkBY7SeFKluM',
#    'plus_code': {'compound_code': '2XJH+JH Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XJH+JH'},
#    'rating': 5,
#    'reference': 'ChIJm3RjAGcZlwARkBY7SeFKluM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Arraial do Cabo'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -22.9665107, 'lng': -42.028249},
#     'viewport': {'northeast': {'lat': -22.9651887697085,
#       'lng': -42.0269123697085},
#      'southwest': {'lat': -22.9678867302915, 'lng': -42.0296103302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Apartamento Da Praça',
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105006410427434534601">Talita Matos</a>'],
#      'photo_reference': 'CmRaAAAAHInRkwcHQGz51sENlsvw3BGJQPrtS47ldnjN33d4oA0DG4u4VyI9vqeaz-xue4pObSZz_v5V5WNtf0poBwOZZxbt3iDXGIXkouYSJE1bLfQZ6onGpf4YAv0AVwc-10byEhBn2GZuIqHMhTHsKh7yv1DPGhQH-bGr_tO9KgMI3QfcLACOxWBaag',
#      'width': 3000}],
#    'place_id': 'ChIJyz0sKWUZlwARv6aQ47l7ovg',
#    'plus_code': {'compound_code': '2XMC+9P Centro, Arraial do Cabo - State of Rio de Janeiro, Brazil',
#     'global_code': '589V2XMC+9P'},
#    'rating': 4.1,
#    'reference': 'ChIJyz0sKWUZlwARv6aQ47l7ovg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 10,
#    'vicinity': 'Rua Dom Pedro I, 13 - Centro, Arraial do Cabo'}],
#  'status': 'OK'}

# %%
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.
vacation_start = vacation_df.loc[vacation_df['City'] == 'Arraial Do Cabo']
vacation_end = vacation_df.loc[vacation_df['City'] == 'Arraial Do Cabo']
vacation_stop1 = vacation_df.loc[vacation_df['City'] == 'Natal']
vacation_stop2 = vacation_df.loc[vacation_df['City'] == 'Touros'] 
vacation_stop3 = vacation_df.loc[vacation_df['City'] == 'Sao Joao Da Barra']

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = (vacation_start['Lat'].to_numpy()[0], vacation_start['Lng'].to_numpy()[0])
end = (vacation_end['Lat'].to_numpy()[0], vacation_end['Lng'].to_numpy()[0])
stop1 = (vacation_stop1['Lat'].to_numpy()[0], vacation_stop1['Lng'].to_numpy()[0])
stop2 = (vacation_stop2['Lat'].to_numpy()[0], vacation_stop2['Lng'].to_numpy()[0])
stop3 = (vacation_stop3['Lat'].to_numpy()[0], vacation_stop3['Lng'].to_numpy()[0])

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure(center=(51.5, 5.2), zoom_level = 18.5)
round_trip = gmaps.directions_layer(start, end, waypoints=[stop1, stop2, stop3], travel_mode = 'DRIVING' or 'BICYCLING' or 'WALKING')
fig.add_layer(round_trip)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID               City Country  Max Temp Current Description    Lat  \
# 0       18    Arraial Do Cabo      BR      75.2       broken clouds -22.97
# 1      100              Natal      BR      82.4       broken clouds  -5.79
# 2      141             Touros      BR      84.2          few clouds  -5.20
# 3      142  Sao Joao Da Barra      BR      75.2       broken clouds -21.64
#
#      Lng                Hotel Name
# 0 -42.03       Pousada Porto Praia
# 1 -35.21  Villa Park Hotel | Natal
# 2 -35.46           INN NEW HORIZON
# 3 -41.05   Pousada Porto De Canoas

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
max_temp = itinerary_df['Max Temp']
fig = gmaps.figure(center=(30.0, 31.0), zoom_level = 2.5)
heat_layer = gmaps.heatmap_layer(locations, weights = max_temp, dissipating = False, max_intensity = 300, point_radius = 4)
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
